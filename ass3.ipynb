# %%
import numpy as np
import pandas as pd

# %%
am_df=pd.read_csv('movies_metadata.csv', encoding ='latin-1', sep=',')

# %%
#details Of Columns and Genres

columns_n_genres = am_df[['title', 'genres']]
print("Details of title and genres:")
print(columns_n_genres)
# Out:
# Details of title and genres:
#                                                 title  \
# 0                                           Toy Story
# 1                                             Jumanji
# 2                                    Grumpier Old Men
# 3                                   Waiting to Exhale
# 4                         Father of the Bride Part II
# 5                                                Heat
# 6                                             Sabrina
# 7                                        Tom and Huck
# 8                                        Sudden Death
# 9                                           GoldenEye
# 10                             The American President
# 11                        Dracula: Dead and Loving It
# 12                                              Balto
# 13                                              Nixon
# 14                                   Cutthroat Island
# 15                                             Casino
# ...

# %%
#Details of the movie 'Grumpier Old Men'
am_df = am_df.set_index('title')
grumpier_old_man = am_df.loc['Grumpier Old Men']
print("Details of the movie 'Grumpier Old Men:")
print(grumpier_old_man)
# Out:
# Details of the movie 'Grumpier Old Men:
# adult                                                                False
# belongs_to_collection    {'id': 119050, 'name': 'Grumpy Old Men Collect...
# budget                                                                   0
# genres                   [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# homepage                                                               NaN
# id                                                                   15602
# imdb_id                                                          tt0113228
# original_language                                                       en
# original_title                                            Grumpier Old Men
# overview                 A family wedding reignites the ancient feud be...
# popularity                                                         11.7129
# poster_path                               /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg
# ...
