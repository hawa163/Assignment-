# %%
import numpy as np
import pandas as pd

# %%
am_df=pd.read_csv('movies_metadata.csv', encoding ='latin-1', sep=',')

# %%
#how to displat the first 10 row
ten_rows = am_df.head(10)
print("First 10 rows")
print(ten_rows)
# Out:
# First 10 rows
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 5  False                                                NaN  60000000
# 6  False                                                NaN  58000000
# 7  False                                                NaN         0
# 8  False                                                NaN  35000000
# 9  False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# ...

# %%
# Create a smaller dataframe
am_small_df = am_df[['title', 'release_date', 'budget', 'revenue', 'runtime']]
releaseDate = am_small_df.sort_values('release_date')
print("DataFrame of release date.")
print(releaseDate)
# Out:
# DataFrame of release date.
#                                                 title  \
# 36                             Across the Sea of Time
# 26                                       Now and Then
# 20                                         Get Shorty
# 24                                  Leaving Las Vegas
# 23                                             Powder
# 21                                            Copycat
# 0                                           Toy Story
# 45                      How To Make An American Quilt
# 41                                    Dead Presidents
# 22                                          Assassins
# 18                     Ace Ventura: When Nature Calls
# 9                                           GoldenEye
# 10                             The American President
# 37                                       It Takes Two
# 19                                        Money Train
# 15                                             Casino
# ...
